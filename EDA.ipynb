# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/tnt_clean.csv',index_col='Date',parse_dates=True)

# %%
df.head()
# Out:
#             Unnamed: 0 Item ID                    Description Customer ID  \
# Date
# 2018-01-02           1  C10017          Chicken Jumbo Leg #40      GAF001
# 2018-01-02           2  C10021     Chicken Leg Meat Fresh #40      JOY001
# 2018-01-02           3  C10007  Chicken Breast Meat Fresh #40      JOY001
# 2018-01-02           4  C10021     Chicken Leg Meat Fresh #40      CIN001
# 2018-01-02           5  B10006                Beef Chuck Roll      CIN001
#
#                               Customer Name     Type  Quantity  Unit Price  \
# Date
# 2018-01-02                   TL Foods, Inc.  Invoice  40000.00        0.45
# 2018-01-02  Joy Fresh Marketing World, Inc.  Invoice   1600.00        1.01
# 2018-01-02  Joy Fresh Marketing World, Inc.  Invoice     80.00        1.09
# 2018-01-02                            Cindy  Invoice   1200.00        1.00
# 2018-01-02                            Cindy  Invoice    274.97        2.49
#
#            Invoice No.  Invoice Total
# Date
# ...

# %%
df = df[['Invoice Total']]

# %%
df = df.groupby('Date').sum()

# %%
df.tail()
# Out:
#             Invoice Total
# Date
# 2019-08-28     82835.5644
# 2019-08-29     57668.7327
# 2019-08-30     51235.4217
# 2019-08-31     31737.1322
# 2019-09-03     62556.7181

# %%
df['Invoice Total'].resample('M').sum().plot.bar()
plt.title('Monthly Sales Volume')
# Out:
# Text(0.5, 1.0, 'Monthly Sales Volume')

# %%
df['Invoice Total'].resample('M').max().plot.bar()
plt.title('Monthly Largest Order')
# Out:
# Text(0.5, 1.0, 'Monthly Largest Order')

# %%
df['Invoice Total'].resample('M').mean().plot.bar()
plt.title('Avg Order Size by Month')
# Out:
# Text(0.5, 1.0, 'Avg Order Size by Month')

# %%
df['Invoice Total'].resample('W').mean().plot.bar(figsize=(20,6))
plt.title('Weekly Sales Volume')
# Out:
# Text(0.5, 1.0, 'Weekly Sales Volume')

# %%
df['Invoice Total'].resample('Y').max()
# Out:
# Date
# 2018-12-31    174228.2488
# 2019-12-31    261572.7844
# Freq: A-DEC, Name: Invoice Total, dtype: float64

# %%
df.plot(y='Invoice Total',figsize=(9,6))

# %%
df['Invoice Total'].plot(figsize=(12,6))

# %%
df['Invoice Total'].plot(figsize=(12,6))
df.rolling(window=30).mean()['Invoice Total'].plot()

# %%
df['Invoice Total: 30 Day Mean'] = df['Invoice Total'].rolling(window=30).mean()

# %%
df.head()
# Out:
#             Invoice Total  Invoice Total: 30 Day Mean
# Date
# 2018-01-02     86617.0987                         NaN
# 2018-01-03     63102.4602                         NaN
# 2018-01-04     79940.6172                         NaN
# 2018-01-05     72043.3550                         NaN
# 2018-01-06     31620.7251                         NaN

# %%
df.plot(figsize=(12,6))
plt.title('Daily Order Total vs 30 Day Average')
# Out:
# Text(0.5, 1.0, 'Daily Order Total vs 30 Day Average')

# %%
df.head()
# Out:
#             Invoice Total  Invoice Total: 30 Day Mean
# Date
# 2018-01-02     86617.0987                         NaN
# 2018-01-03     63102.4602                         NaN
# 2018-01-04     79940.6172                         NaN
# 2018-01-05     72043.3550                         NaN
# 2018-01-06     31620.7251                         NaN

# %% [markdown]
# ## Expanded Average

# %%
df['Invoice Total'].expanding().mean().plot(figsize=(12,6))

# %%
df.plot()

# %%
df['Invoice Total'].plot();

# %%
title = 'TITLE'
ylabel = 'Y LABEL'
xlabel = 'X LABEL'

# %%
ax = df['Invoice Total'].plot(figsize=(12,6),title=title)
ax.autoscale(axis='both',tight=True)
ax.set(xlabel=xlabel,ylabel=ylabel)
;
# Out:
# ''

# %%
df['Invoice Total']['2018-01-01':'2018-12-31'].plot(figsize=(12,6))

# %%
df['Invoice Total'].plot(figsize=(12,6),xlim=['2018-01-01','2018-12-31'])
;
# Out:
# ''

# %%
df['Invoice Total'].plot(figsize=(12,6),ylim=[0,200000],ls='--',c='green')
;
# Out:
# ''

# %%
from matplotlib import dates

# %%
ax = df['Invoice Total'].plot(xlim=['2018-01-01','2018-03-01'],ylim=[10000,200000],figsize=(12,6))
ax.set(xlabel='')
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
ax.xaxis.set_major_formatter(dates.DateFormatter('%d'))

ax.xaxis.set_minor_locator(dates.MonthLocator())
ax.xaxis.set_minor_formatter(dates.DateFormatter('\n\n%b'))

ax.yaxis.grid(True)
ax.xaxis.grid(True)
;
# Out:
# ''

# %%
df.head(20)
# Out:
#             Invoice Total  Invoice Total: 30 Day Mean
# Date
# 2018-01-02   86617.098700                         NaN
# 2018-01-03   63102.460200                         NaN
# 2018-01-04   79940.617200                         NaN
# 2018-01-05   72043.355000                         NaN
# 2018-01-06   31620.725100                         NaN
# 2018-01-08   94514.574600                         NaN
# 2018-01-09   79639.792400                         NaN
# 2018-01-10   61361.736900                         NaN
# 2018-01-11   88489.007100                         NaN
# 2018-01-12   61221.678800                         NaN
# 2018-01-13   50387.825937                         NaN
# 2018-01-15   95981.008300                         NaN
# 2018-01-16   68239.940600                         NaN
# 2018-01-17   81214.736100                         NaN
# 2018-01-18   95872.324700                         NaN
# 2018-01-19   67177.303600                         NaN
# ...

# %%
df.plot()

# %%
df=df[['Invoice Total']]

# %%
df['Month'] = df.index.month
# Out:
# /Users/esotewic/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#             Invoice Total  Month
# Date
# 2018-01-02     86617.0987      1
# 2018-01-03     63102.4602      1
# 2018-01-04     79940.6172      1
# 2018-01-05     72043.3550      1
# 2018-01-06     31620.7251      1

# %%
df.boxplot(by='Month',figsize=(12,6))
plt.title('Distribution of Invoice Totals')
# Out:
# Text(0.5, 1.0, 'Distribution of Invoice Totals')

# %%
df.tail()
# Out:
#             Invoice Total
# Date
# 2019-08-28     82835.5644
# 2019-08-29     57668.7327
# 2019-08-30     51235.4217
# 2019-08-31     31737.1322
# 2019-09-03     62556.7181
